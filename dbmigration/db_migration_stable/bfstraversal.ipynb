# %%
# !pip install pandas
# !pip install sqlalchemy

import os
import pandas as pd
import psycopg2
import io
import csv
import json
import datetime
import decimal
import sqlalchemy
from sqlalchemy import create_engine, MetaData, inspect, event, text
from collections import deque
from queue import Queue
from collections import deque

import pandas as pd
# Database connection parameters
# Database connection parameters are now retrieved from environment variables
db_params = {
    'host': os.getenv('DB_HOST', 'default_host'),
    'dbname': os.getenv('DB_NAME', 'default_db_name'),
    'user': os.getenv('DB_USER', 'default_user'),
    'password': os.getenv('DB_PASSWORD', 'default_password'),
    'port': int(os.getenv('DB_PORT', '5432'))  # Default port number if not specified
}

def get_table_columns(engine, schema_name, table_name, excluded_columns):
    """
    Retrieve column names for a given table excluding certain columns.
    """
    query = sqlalchemy.text("""
        SELECT column_name 
        FROM information_schema.columns 
        WHERE table_schema = :schema_name AND table_name = :table_name;
    """)

    with engine.connect() as conn:
        result = conn.execute(query, {'schema_name': schema_name, 'table_name': table_name})
        columns = [row[0] for row in result.fetchall() if row[0] not in excluded_columns]
    
    return columns
def construct_select_clause(schema_name, table_name, columns):
    """
    Construct a SELECT clause for a given table.
    """
    return ', '.join([f'"{schema_name}"."{table_name}"."{col}"' for col in columns])

# Adjusted construct_join_query function
# Adjusted construct_join_query function
# Adjusted construct_join_query function to include previous joins and where clause
def construct_join_query(schema_name, starting_table, joined_table, starting_table_column, joined_table_column, key_value, previous_joins, where_clause):
    """
    Construct a full JOIN query with all columns from the joined table, incorporating the schema name, previous joins, and where clause.
    Ensure each table is only joined once.
    """
    # Construct the new join condition
    new_join_condition = f'LEFT JOIN \"{schema_name}\".\"{joined_table}\" ON \"{schema_name}\".\"{starting_table}\".\"{starting_table_column}\" = \"{schema_name}\".\"{joined_table}\".\"{joined_table_column}\"'
    
    # Combine previous joins with the new join condition
    combined_joins = f"{previous_joins} {new_join_condition}"

    # Construct the full join query string
    full_join_query_str = f"SELECT DISTINCT \"{schema_name}\".\"{joined_table}\".* FROM \"{schema_name}\".\"{starting_table}\" {combined_joins} {where_clause}"
    return text(full_join_query_str)
# Establishing the connection
db_url = f"postgresql+psycopg2://{db_params['user']}:{db_params['password']}@{db_params['host']}:{db_params['port']}/{db_params['dbname']}"
engine = create_engine(db_url)

       
    

# Set the schema for this session
schema_name = os.getenv('DB_SCHEMA', 'default_schema')  # Retrieve schema name from environment variable

@event.listens_for(engine, "connect")
def set_search_path(dbapi_connection, connection_record):
    cursor = dbapi_connection.cursor()
    cursor.execute(f"SET search_path TO {schema_name};")
    cursor.close()
# with conn.cursor() as cur:
#     cur.execute(f"SET search_path TO {schema_name};")

# Define a default JSON object for fields that are None
default_json = {}  # Update this with a suitable default JSON object
empty_placeholder = "\\N"  # Placeholder for empty fields in .dump file

with engine.connect() as conn:
        print("Successfully connected to the database!")
        conn.execute(text(f"SET search_path TO {schema_name};"))
def export_table_data(query, params, connections, common_dump_file_name, schema_name, table_name, export_format='text', export_path='/app/outputs', log_file_name='query_log.txt',tables_file='tables_log.txt', CHUNK_SIZE=10000):
    if not os.path.exists(export_path):
        os.makedirs(export_path)

    log_file_path = os.path.join(export_path, log_file_name)
    dump_file_path = os.path.join(export_path, f"{common_dump_file_name}.csv")
    tables_file_path = os.path.join(export_path, tables_file)

    # with open(log_file_path, 'a', encoding='utf-8') as log_file:
    #     # Convert the query object to a string
    #     query_str = str(query)

    #     # Manually replace the parameter placeholder with its value
    #     # Make sure to convert the parameter to a string if it's not already one
    #     # Use repr() to handle string parameters correctly by adding quotes
    #     if isinstance(params['key_value'], str):
    #         param_value = repr(params['key_value'])
    #     else:
    #         param_value = str(params['key_value'])

    #     query_str_with_params = query_str.replace(":key_value", param_value)

    #     # Write the modified query to the log file
    #     #log_file.write(f"{query_str_with_params}\n")
    #     log_file.write(f"Table: {table_name}\n{query_str_with_params}\n")
    with open(log_file_path, 'a', encoding='utf-8') as log_file:
        # Convert the query object to a string
        query_str = str(query)

        # Manually replace the parameter placeholder with its value
        # Use repr() to handle string parameters correctly by adding quotes
        param_value = repr(params['key_value']) if isinstance(params['key_value'], str) else str(params['key_value'])
        query_str_with_params = query_str.replace(":key_value", param_value)

        # Write the modified query to the log file
        log_file.write(f"Table: {table_name}\n{query_str_with_params}\n")

    with open(tables_file_path, 'a', encoding='utf-8') as tables_file:
        # Write the modified query to the log file
        #log_file.write(f"{query_str_with_params}\n")
        tables_file.write(f"Table: {table_name}\n")
  
    with engine.connect() as connection:
        try:
            first_chunk = True
            print(f"running for table -> {table_name} chunks with params {params} ----the query {query}")
            for chunk in pd.read_sql_query(query, connection, params=params, chunksize=CHUNK_SIZE):
                if first_chunk:
                    # Write column names and COPY command only for the first chunk
                    column_names = '\t '.join(chunk.columns)
                    header_str = f"{schema_name}.{table_name}\n{column_names}\n"  # Removed the closing parenthesis
                    first_chunk = False
                else:
                    header_str = ''

                chunk.dropna(how='all', inplace=True)

                # Convert the DataFrame to a CSV formatted string
                csv_string = chunk.to_csv(sep='\t', index=False, header=False)

                # Append the header and CSV string to the dump file
                with open(dump_file_path, 'a', encoding='utf-8') as dump_file:
                    dump_file.write(header_str + csv_string)

            # # Write the end-of-data marker
            with open(dump_file_path, 'a', encoding='utf-8') as dump_file:
                dump_file.write("\n")

        except Exception as e:
            print(f"An error occurred: {e}")

    print(f"Data appended to {dump_file_path} with query logged in {log_file_path}")

    

def generate_truncate_sql(export_path, related_tables):
    truncate_file_path = os.path.join(export_path, "truncate_tables.sql")
    with open(truncate_file_path, 'w', encoding='utf-8') as truncate_file:
        for table in related_tables:
            truncate_file.write(f"TRUNCATE TABLE {schema_name}.{table} restart identity cascade;\n")
    print(f"Truncate script created at {truncate_file_path}")


def get_key_value(table, column, value, connection):
    """
    Fetch the corresponding key value from a table based on a column and its value.
    """
    query = f"SELECT {column} FROM {table} WHERE {column} = %s;"
    with connection.cursor() as cur:
        cur.execute(query, [value])
        result = cur.fetchone()
        return result[0] if result else None



def find_related_tables_bfs(engine, starting_table, start_table_key_column, key_value, common_dump_file_name, schema_name, excluded_tables=None, excluded_columns=None):
    if excluded_tables is None:
        excluded_tables = set()
    if excluded_columns is None:
        excluded_columns = {'modified_by_id', 'created_by_id'}

    queue = deque([(starting_table, '')])
    visited = set()

    while queue:
        current_table, previous_joins = queue.popleft()

        where_clause = f'WHERE "{schema_name}"."{starting_table}"."{start_table_key_column}" = :key_value'
       
        if current_table == starting_table:
            visited.add(current_table)
            initial_query_str = f'SELECT DISTINCT * FROM "{schema_name}"."{current_table}"  WHERE "{schema_name}"."{starting_table}"."{start_table_key_column}" = :key_value'
            # Convert the string query to a SQLAlchemy text object
            initial_query = text(initial_query_str)
            with engine.connect() as conn:
                export_table_data(initial_query, {'key_value': key_value}, conn, common_dump_file_name, schema_name, current_table, export_format='text')

        foreign_key_query = """
        SELECT DISTINCT
            tc.table_name AS primary_table, 
            kcu.column_name AS primary_column, 
            ccu.table_name AS foreign_table_name,
            ccu.column_name AS foreign_column
        FROM 
            information_schema.table_constraints AS tc 
            JOIN information_schema.key_column_usage AS kcu 
            ON tc.constraint_name = kcu.constraint_name
            JOIN information_schema.constraint_column_usage AS ccu 
            ON ccu.constraint_name = tc.constraint_name
        WHERE 
            tc.constraint_type = 'FOREIGN KEY' AND 
            (tc.table_name = :current_table OR ccu.table_name = :current_table);
        """
        print(f"Current to process table  TO {current_table} previous JOINS joins: {previous_joins}")
        with engine.connect() as conn:
            result = conn.execute(sqlalchemy.text(foreign_key_query), {'current_table': current_table})
            rows = result.fetchall()
            print(f"Current to process table  TO {current_table} previous RESULTS FETCHED: {rows}")
            for row in rows:
                primary_table, primary_column, foreign_table_name, foreign_column = row

                
                print(f"Current to process table  TO {current_table} prIMARY: {primary_table}, COL {primary_column} foreign {foreign_table_name} col {foreign_column}")
                # Skip processing for excluded columns
                if primary_column in excluded_columns or foreign_column in excluded_columns:
                    print(f"SKIIIIIIIIIIIIIIIIIIIIIP")
                    continue
                if primary_table != current_table: 
                # Usage of construct_join_query in your code
                    if primary_table not in visited and primary_table not in excluded_tables:
                        new_join_condition = f'LEFT JOIN \"{schema_name}\".\"{primary_table}\" ON \"{schema_name}\".\"{foreign_table_name}\".\"{foreign_column}\" = \"{schema_name}\".\"{primary_table}\".\"{primary_column}\"'
                        #full_join_query = construct_join_query(schema_name, foreign_table_name, primary_table, foreign_column, primary_column, key_value, previous_joins, where_clause)
                        full_join_query =  f"SELECT DISTINCT \"{schema_name}\".\"{primary_table}\".* FROM \"{schema_name}\".\"{starting_table}\"  {previous_joins}  {new_join_condition} {where_clause} AND \"{schema_name}\".\"{primary_table}\".\"{primary_column}\" IS NOT NULL"
                        
                        export_table_data(full_join_query, {'key_value': key_value}, conn, common_dump_file_name, schema_name, primary_table, export_format='text')
                        next_joins = f"{previous_joins} {new_join_condition}"
                        print(f"APPENDING TO {primary_table} next joins: {next_joins}")
                        queue.append((primary_table, next_joins))
                        visited.add(primary_table)
                        
                elif foreign_table_name != current_table:
                    if foreign_table_name not in visited and foreign_table_name not in excluded_tables:
                        new_join_condition = f'LEFT JOIN \"{schema_name}\".\"{foreign_table_name}\" ON \"{schema_name}\".\"{primary_table}\".\"{primary_column}\" = \"{schema_name}\".\"{foreign_table_name}\".\"{foreign_column}\"'
                        #full_join_query = construct_join_query(schema_name, primary_table, foreign_table_name, primary_column, foreign_column, key_value, previous_joins, where_clause)
                        full_join_query =  f"SELECT DISTINCT \"{schema_name}\".\"{foreign_table_name}\".* FROM \"{schema_name}\".\"{starting_table}\" {previous_joins} {new_join_condition} {where_clause} AND \"{schema_name}\".\"{foreign_table_name}\".\"{foreign_column}\" IS NOT NULL"
                        export_table_data(full_join_query, {'key_value': key_value}, conn, common_dump_file_name, schema_name, foreign_table_name, export_format='text')
                        next_joins = f"{previous_joins} {new_join_condition}"
                        print(f"APPENDING TO {foreign_table_name} next joins: {next_joins}")
                        queue.append((foreign_table_name, next_joins))
                        visited.add(foreign_table_name)
                    # Process each foreign key relationship
                    # Your existing logic for handling relationships goes here

    #return visited  # Optionally return the visited set for further analysis
    return visited  # Optionally return the visited set for further analysis

# Usage example
common_dump_file_name = "brands_dump"
# Retrieve script parameters from environment variables

db_params = {
    'host': os.getenv('DB_HOST', 'default_host'),
    'dbname': os.getenv('DB_NAME', 'default_db_name'),
    'user': os.getenv('DB_USER', 'default_user'),
    'password': os.getenv('DB_PASSWORD', 'default_password'),
    'port': int(os.getenv('DB_PORT', '5432'))  # Default port number if not specified
}


starting_table = os.getenv('STARTING_TABLE', 'default_value_for_starting_table')
starting_key_column = os.getenv('STARTING_KEY_COLUMN', 'default_value_for_starting_key_column')

# For 'key_value', handle different data types (string/int)
key_value_str = os.getenv('KEY_VALUE', 'default_value_for_key_value')
try:
    key_value = int(key_value_str)
except ValueError:
    key_value = key_value_str  # Use the string value if it's not an integer

# Split the excluded tables into a list if they are provided as a comma-separated string
excluded_tables_str = os.getenv('EXCLUDED_TABLES', '')
excluded_tables = excluded_tables_str.split(',') if excluded_tables_str else []

# Global chunk size for data processing
CHUNK_SIZE = 10000  # You can adjust this value as needed
print("Hierarchy starting from '{}', for key '{}': {}".format(starting_table, starting_key_column, key_value))
related_tables = find_related_tables_bfs(engine,starting_table, starting_key_column, key_value, common_dump_file_name, schema_name, excluded_tables=excluded_tables)
#def find_related_tables_bfs(engine, starting_table, start_table_key_column, key_value, common_dump_file_name, schema_name, excluded_tables=None, excluded_columns=None):
  
print(f"Related tables: {related_tables}")


# Specify the file path where you want to save the output
output_file_path = '/app/exports/related_tables_output.txt'

# Writing the related tables to a file
with open(output_file_path, 'w') as file:
    for table in related_tables:
        file.write(f"{table}\n")

print(f"Related tables have been written to {output_file_path}")

generate_truncate_sql('/app/exports/', related_tables)
#engine.dispose()
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/ubuntu/.local/lib/python3.10/site-packages (2.1.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy<2,>=1.22.4 in /home/ubuntu/.local/lib/python3.10/site-packages (from pandas) (1.26.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/ubuntu/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sqlalchemy in /home/ubuntu/.local/lib/python3.10/site-packages (2.0.23)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from sqlalchemy) (4.8.0)
# Requirement already satisfied: greenlet!=0.4.17 in /home/ubuntu/.local/lib/python3.10/site-packages (from sqlalchemy) (3.0.1)
# Successfully connected to the database!
# Hierarchy starting from 'app_brands', for key 'id': 263
# running for table -> app_brands chunks with params {'key_value': 263} ----the query SELECT DISTINCT * FROM "psp"."app_brands"  WHERE "psp"."app_brands"."id" = :key_value
# Data appended to exports/brands_dump.csv with query logged in exports/query_log.txt
# Current to process table  TO app_brands previous JOINS joins:
# Current to process table  TO app_brands previous RESULTS FETCHED: [('app_api_keys', 'brand_id', 'app_brands', 'id'), ('app_availability_rules', 'brand_id', 'app_brands', 'id'), ('app_deposits', 'brand_id', 'app_brands', 'id'), ('app_payment_request_log', 'brand_id', 'app_brands', 'id'), ('app_psp_settings', 'brand_id', 'app_brands', 'id'), ('app_user_brands', 'brand_id', 'app_brands', 'id')]
# Current to process table  TO app_brands prIMARY: app_api_keys, COL brand_id foreign app_brands col id
# running for table -> app_api_keys chunks with params {'key_value': 263} ----the query SELECT DISTINCT "psp"."app_api_keys".* FROM "psp"."app_brands"    LEFT JOIN "psp"."app_api_keys" ON "psp"."app_brands"."id" = "psp"."app_api_keys"."brand_id" WHERE "psp"."app_brands"."id" = :key_value AND "psp"."app_api_keys"."brand_id" IS NOT NULL
# An error occurred: (psycopg2.errors.SyntaxError) syntax error at or near ":"
# LINE 1: ..._keys"."brand_id" WHERE "psp"."app_brands"."id" = :key_value...
#                                                              ^
#
# [SQL: SELECT DISTINCT "psp"."app_api_keys".* FROM "psp"."app_brands"    LEFT JOIN "psp"."app_api_keys" ON "psp"."app_brands"."id" = "psp"."app_api_keys"."brand_id" WHERE "psp"."app_brands"."id" = :key_value AND "psp"."app_api_keys"."brand_id" IS NOT NULL]
# [parameters: {'key_value': 263}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# Data appended to exports/brands_dump.csv with query logged in exports/query_log.txt
# APPENDING TO app_api_keys next joins:  LEFT JOIN "psp"."app_api_keys" ON "psp"."app_brands"."id" = "psp"."app_api_keys"."brand_id"
# Current to process table  TO app_brands prIMARY: app_availability_rules, COL brand_id foreign app_brands col id
# running for table -> app_availability_rules chunks with params {'key_value': 263} ----the query SELECT DISTINCT "psp"."app_availability_rules".* FROM "psp"."app_brands"    LEFT JOIN "psp"."app_availability_rules" ON "psp"."app_brands"."id" = "psp"."app_availability_rules"."brand_id" WHERE "psp"."app_brands"."id" = :key_value AND "psp"."app_availability_rules"."brand_id" IS NOT NULL
# An error occurred: (psycopg2.errors.SyntaxError) syntax error at or near ":"
# LINE 1: ...rules"."brand_id" WHERE "psp"."app_brands"."id" = :key_value...
#                                                              ^
#
# [SQL: SELECT DISTINCT "psp"."app_availability_rules".* FROM "psp"."app_brands"    LEFT JOIN "psp"."app_availability_rules" ON "psp"."app_brands"."id" = "psp"."app_availability_rules"."brand_id" WHERE "psp"."app_brands"."id" = :key_value AND "psp"."app_availability_rules"."brand_id" IS NOT NULL]
# [parameters: {'key_value': 263}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# Data appended to exports/brands_dump.csv with query logged in exports/query_log.txt
# APPENDING TO app_availability_rules next joins:  LEFT JOIN "psp"."app_availability_rules" ON "psp"."app_brands"."id" = "psp"."app_availability_rules"."brand_id"
# Current to process table  TO app_brands prIMARY: app_deposits, COL brand_id foreign app_brands col id
# running for table -> app_deposits chunks with params {'key_value': 263} ----the query SELECT DISTINCT "psp"."app_deposits".* FROM "psp"."app_brands"    LEFT JOIN "psp"."app_deposits" ON "psp"."app_brands"."id" = "psp"."app_deposits"."brand_id" WHERE "psp"."app_brands"."id" = :key_value AND "psp"."app_deposits"."brand_id" IS NOT NULL
# An error occurred: (psycopg2.errors.SyntaxError) syntax error at or near ":"
# LINE 1: ...osits"."brand_id" WHERE "psp"."app_brands"."id" = :key_value...
#                                                              ^
#
# [SQL: SELECT DISTINCT "psp"."app_deposits".* FROM "psp"."app_brands"    LEFT JOIN "psp"."app_deposits" ON "psp"."app_brands"."id" = "psp"."app_deposits"."brand_id" WHERE "psp"."app_brands"."id" = :key_value AND "psp"."app_deposits"."brand_id" IS NOT NULL]
# [parameters: {'key_value': 263}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# Data appended to exports/brands_dump.csv with query logged in exports/query_log.txt
# APPENDING TO app_deposits next joins:  LEFT JOIN "psp"."app_deposits" ON "psp"."app_brands"."id" = "psp"."app_deposits"."brand_id"
# Current to process table  TO app_brands prIMARY: app_payment_request_log, COL brand_id foreign app_brands col id
# running for table -> app_payment_request_log chunks with params {'key_value': 263} ----the query SELECT DISTINCT "psp"."app_payment_request_log".* FROM "psp"."app_brands"    LEFT JOIN "psp"."app_payment_request_log" ON "psp"."app_brands"."id" = "psp"."app_payment_request_log"."brand_id" WHERE "psp"."app_brands"."id" = :key_value AND "psp"."app_payment_request_log"."brand_id" IS NOT NULL
# An error occurred: (psycopg2.errors.SyntaxError) syntax error at or near ":"
# LINE 1: ...t_log"."brand_id" WHERE "psp"."app_brands"."id" = :key_value...
#                                                              ^
#
# [SQL: SELECT DISTINCT "psp"."app_payment_request_log".* FROM "psp"."app_brands"    LEFT JOIN "psp"."app_payment_request_log" ON "psp"."app_brands"."id" = "psp"."app_payment_request_log"."brand_id" WHERE "psp"."app_brands"."id" = :key_value AND "psp"."app_payment_request_log"."brand_id" IS NOT NULL]
# [parameters: {'key_value': 263}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# Data appended to exports/brands_dump.csv with query logged in exports/query_log.txt
# APPENDING TO app_payment_request_log next joins:  LEFT JOIN "psp"."app_payment_request_log" ON "psp"."app_brands"."id" = "psp"."app_payment_request_log"."brand_id"
# Current to process table  TO app_brands prIMARY: app_psp_settings, COL brand_id foreign app_brands col id
# running for table -> app_psp_settings chunks with params {'key_value': 263} ----the query SELECT DISTINCT "psp"."app_psp_settings".* FROM "psp"."app_brands"    LEFT JOIN "psp"."app_psp_settings" ON "psp"."app_brands"."id" = "psp"."app_psp_settings"."brand_id" WHERE "psp"."app_brands"."id" = :key_value AND "psp"."app_psp_settings"."brand_id" IS NOT NULL
# An error occurred: (psycopg2.errors.SyntaxError) syntax error at or near ":"
# LINE 1: ...tings"."brand_id" WHERE "psp"."app_brands"."id" = :key_value...
#                                                              ^
#
# [SQL: SELECT DISTINCT "psp"."app_psp_settings".* FROM "psp"."app_brands"    LEFT JOIN "psp"."app_psp_settings" ON "psp"."app_brands"."id" = "psp"."app_psp_settings"."brand_id" WHERE "psp"."app_brands"."id" = :key_value AND "psp"."app_psp_settings"."brand_id" IS NOT NULL]
# [parameters: {'key_value': 263}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# Data appended to exports/brands_dump.csv with query logged in exports/query_log.txt
# APPENDING TO app_psp_settings next joins:  LEFT JOIN "psp"."app_psp_settings" ON "psp"."app_brands"."id" = "psp"."app_psp_settings"."brand_id"
# Current to process table  TO app_brands prIMARY: app_user_brands, COL brand_id foreign app_brands col id
# running for table -> app_user_brands chunks with params {'key_value': 263} ----the query SELECT DISTINCT "psp"."app_user_brands".* FROM "psp"."app_brands"    LEFT JOIN "psp"."app_user_brands" ON "psp"."app_brands"."id" = "psp"."app_user_brands"."brand_id" WHERE "psp"."app_brands"."id" = :key_value AND "psp"."app_user_brands"."brand_id" IS NOT NULL
# An error occurred: (psycopg2.errors.SyntaxError) syntax error at or near ":"
# LINE 1: ...rands"."brand_id" WHERE "psp"."app_brands"."id" = :key_value...
#                                                              ^
#
# [SQL: SELECT DISTINCT "psp"."app_user_brands".* FROM "psp"."app_brands"    LEFT JOIN "psp"."app_user_brands" ON "psp"."app_brands"."id" = "psp"."app_user_brands"."brand_id" WHERE "psp"."app_brands"."id" = :key_value AND "psp"."app_user_brands"."brand_id" IS NOT NULL]
# [parameters: {'key_value': 263}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# Data appended to exports/brands_dump.csv with query logged in exports/query_log.txt
# APPENDING TO app_user_brands next joins:  LEFT JOIN "psp"."app_user_brands" ON "psp"."app_brands"."id" = "psp"."app_user_brands"."brand_id"
# Current to process table  TO app_api_keys previous JOINS joins:  LEFT JOIN "psp"."app_api_keys" ON "psp"."app_brands"."id" = "psp"."app_api_keys"."brand_id"
# Current to process table  TO app_api_keys previous RESULTS FETCHED: [('app_api_keys', 'brand_id', 'app_brands', 'id')]
# Current to process table  TO app_api_keys prIMARY: app_api_keys, COL brand_id foreign app_brands col id
# Current to process table  TO app_availability_rules previous JOINS joins:  LEFT JOIN "psp"."app_availability_rules" ON "psp"."app_brands"."id" = "psp"."app_availability_rules"."brand_id"
# Current to process table  TO app_availability_rules previous RESULTS FETCHED: [('app_availability_rules', 'brand_id', 'app_brands', 'id'), ('app_psp_rules', 'rule_id', 'app_availability_rules', 'id')]
# Current to process table  TO app_availability_rules prIMARY: app_availability_rules, COL brand_id foreign app_brands col id
# Current to process table  TO app_availability_rules prIMARY: app_psp_rules, COL rule_id foreign app_availability_rules col id
# running for table -> app_psp_rules chunks with params {'key_value': 263} ----the query SELECT DISTINCT "psp"."app_psp_rules".* FROM "psp"."app_brands"   LEFT JOIN "psp"."app_availability_rules" ON "psp"."app_brands"."id" = "psp"."app_availability_rules"."brand_id"  LEFT JOIN "psp"."app_psp_rules" ON "psp"."app_availability_rules"."id" = "psp"."app_psp_rules"."rule_id" WHERE "psp"."app_brands"."id" = :key_value AND "psp"."app_psp_rules"."rule_id" IS NOT NULL
# An error occurred: (psycopg2.errors.SyntaxError) syntax error at or near ":"
# LINE 1: ..._rules"."rule_id" WHERE "psp"."app_brands"."id" = :key_value...
#                                                              ^
#
# [SQL: SELECT DISTINCT "psp"."app_psp_rules".* FROM "psp"."app_brands"   LEFT JOIN "psp"."app_availability_rules" ON "psp"."app_brands"."id" = "psp"."app_availability_rules"."brand_id"  LEFT JOIN "psp"."app_psp_rules" ON "psp"."app_availability_rules"."id" = "psp"."app_psp_rules"."rule_id" WHERE "psp"."app_brands"."id" = :key_value AND "psp"."app_psp_rules"."rule_id" IS NOT NULL]
# [parameters: {'key_value': 263}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# Data appended to exports/brands_dump.csv with query logged in exports/query_log.txt
# APPENDING TO app_psp_rules next joins:  LEFT JOIN "psp"."app_availability_rules" ON "psp"."app_brands"."id" = "psp"."app_availability_rules"."brand_id" LEFT JOIN "psp"."app_psp_rules" ON "psp"."app_availability_rules"."id" = "psp"."app_psp_rules"."rule_id"
# Current to process table  TO app_deposits previous JOINS joins:  LEFT JOIN "psp"."app_deposits" ON "psp"."app_brands"."id" = "psp"."app_deposits"."brand_id"
# Current to process table  TO app_deposits previous RESULTS FETCHED: [('app_deposit_callbacks', 'deposit_id', 'app_deposits', 'id'), ('app_deposits', 'brand_id', 'app_brands', 'id'), ('app_deposits', 'payment_gateway_id', 'app_psp_settings', 'id'), ('app_fireblocks_address_pool', 'transaction_id', 'app_deposits', 'id'), ('app_form_requests', 'transaction_id', 'app_deposits', 'id'), ('app_log_gateway_callback', 'transaction_id', 'app_deposits', 'id'), ('app_third_party_update_log', 'deposit_id', 'app_deposits', 'id'), ('app_transaction_updates', 'transaction_id', 'app_deposits', 'id')]
# Current to process table  TO app_deposits prIMARY: app_deposit_callbacks, COL deposit_id foreign app_deposits col id
# running for table -> app_deposit_callbacks chunks with params {'key_value': 263} ----the query SELECT DISTINCT "psp"."app_deposit_callbacks".* FROM "psp"."app_brands"   LEFT JOIN "psp"."app_deposits" ON "psp"."app_brands"."id" = "psp"."app_deposits"."brand_id"  LEFT JOIN "psp"."app_deposit_callbacks" ON "psp"."app_deposits"."id" = "psp"."app_deposit_callbacks"."deposit_id" WHERE "psp"."app_brands"."id" = :key_value AND "psp"."app_deposit_callbacks"."deposit_id" IS NOT NULL
# An error occurred: (psycopg2.errors.SyntaxError) syntax error at or near ":"
# LINE 1: ...cks"."deposit_id" WHERE "psp"."app_brands"."id" = :key_value...
#                                                              ^
#
# [SQL: SELECT DISTINCT "psp"."app_deposit_callbacks".* FROM "psp"."app_brands"   LEFT JOIN "psp"."app_deposits" ON "psp"."app_brands"."id" = "psp"."app_deposits"."brand_id"  LEFT JOIN "psp"."app_deposit_callbacks" ON "psp"."app_deposits"."id" = "psp"."app_deposit_callbacks"."deposit_id" WHERE "psp"."app_brands"."id" = :key_value AND "psp"."app_deposit_callbacks"."deposit_id" IS NOT NULL]
# [parameters: {'key_value': 263}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# Data appended to exports/brands_dump.csv with query logged in exports/query_log.txt
# APPENDING TO app_deposit_callbacks next joins:  LEFT JOIN "psp"."app_deposits" ON "psp"."app_brands"."id" = "psp"."app_deposits"."brand_id" LEFT JOIN "psp"."app_deposit_callbacks" ON "psp"."app_deposits"."id" = "psp"."app_deposit_callbacks"."deposit_id"
# Current to process table  TO app_deposits prIMARY: app_deposits, COL brand_id foreign app_brands col id
# Current to process table  TO app_deposits prIMARY: app_deposits, COL payment_gateway_id foreign app_psp_settings col id
# Current to process table  TO app_deposits prIMARY: app_fireblocks_address_pool, COL transaction_id foreign app_deposits col id
# running for table -> app_fireblocks_address_pool chunks with params {'key_value': 263} ----the query SELECT DISTINCT "psp"."app_fireblocks_address_pool".* FROM "psp"."app_brands"   LEFT JOIN "psp"."app_deposits" ON "psp"."app_brands"."id" = "psp"."app_deposits"."brand_id"  LEFT JOIN "psp"."app_fireblocks_address_pool" ON "psp"."app_deposits"."id" = "psp"."app_fireblocks_address_pool"."transaction_id" WHERE "psp"."app_brands"."id" = :key_value AND "psp"."app_fireblocks_address_pool"."transaction_id" IS NOT NULL
# An error occurred: (psycopg2.errors.SyntaxError) syntax error at or near ":"
# LINE 1: ...."transaction_id" WHERE "psp"."app_brands"."id" = :key_value...
#                                                              ^
#
# [SQL: SELECT DISTINCT "psp"."app_fireblocks_address_pool".* FROM "psp"."app_brands"   LEFT JOIN "psp"."app_deposits" ON "psp"."app_brands"."id" = "psp"."app_deposits"."brand_id"  LEFT JOIN "psp"."app_fireblocks_address_pool" ON "psp"."app_deposits"."id" = "psp"."app_fireblocks_address_pool"."transaction_id" WHERE "psp"."app_brands"."id" = :key_value AND "psp"."app_fireblocks_address_pool"."transaction_id" IS NOT NULL]
# [parameters: {'key_value': 263}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# Data appended to exports/brands_dump.csv with query logged in exports/query_log.txt
# APPENDING TO app_fireblocks_address_pool next joins:  LEFT JOIN "psp"."app_deposits" ON "psp"."app_brands"."id" = "psp"."app_deposits"."brand_id" LEFT JOIN "psp"."app_fireblocks_address_pool" ON "psp"."app_deposits"."id" = "psp"."app_fireblocks_address_pool"."transaction_id"
# Current to process table  TO app_deposits prIMARY: app_form_requests, COL transaction_id foreign app_deposits col id
# running for table -> app_form_requests chunks with params {'key_value': 263} ----the query SELECT DISTINCT "psp"."app_form_requests".* FROM "psp"."app_brands"   LEFT JOIN "psp"."app_deposits" ON "psp"."app_brands"."id" = "psp"."app_deposits"."brand_id"  LEFT JOIN "psp"."app_form_requests" ON "psp"."app_deposits"."id" = "psp"."app_form_requests"."transaction_id" WHERE "psp"."app_brands"."id" = :key_value AND "psp"."app_form_requests"."transaction_id" IS NOT NULL
# An error occurred: (psycopg2.errors.SyntaxError) syntax error at or near ":"
# LINE 1: ...."transaction_id" WHERE "psp"."app_brands"."id" = :key_value...
#                                                              ^
#
# [SQL: SELECT DISTINCT "psp"."app_form_requests".* FROM "psp"."app_brands"   LEFT JOIN "psp"."app_deposits" ON "psp"."app_brands"."id" = "psp"."app_deposits"."brand_id"  LEFT JOIN "psp"."app_form_requests" ON "psp"."app_deposits"."id" = "psp"."app_form_requests"."transaction_id" WHERE "psp"."app_brands"."id" = :key_value AND "psp"."app_form_requests"."transaction_id" IS NOT NULL]
# [parameters: {'key_value': 263}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# Data appended to exports/brands_dump.csv with query logged in exports/query_log.txt
# APPENDING TO app_form_requests next joins:  LEFT JOIN "psp"."app_deposits" ON "psp"."app_brands"."id" = "psp"."app_deposits"."brand_id" LEFT JOIN "psp"."app_form_requests" ON "psp"."app_deposits"."id" = "psp"."app_form_requests"."transaction_id"
# Current to process table  TO app_deposits prIMARY: app_log_gateway_callback, COL transaction_id foreign app_deposits col id
# running for table -> app_log_gateway_callback chunks with params {'key_value': 263} ----the query SELECT DISTINCT "psp"."app_log_gateway_callback".* FROM "psp"."app_brands"   LEFT JOIN "psp"."app_deposits" ON "psp"."app_brands"."id" = "psp"."app_deposits"."brand_id"  LEFT JOIN "psp"."app_log_gateway_callback" ON "psp"."app_deposits"."id" = "psp"."app_log_gateway_callback"."transaction_id" WHERE "psp"."app_brands"."id" = :key_value AND "psp"."app_log_gateway_callback"."transaction_id" IS NOT NULL
# An error occurred: (psycopg2.errors.SyntaxError) syntax error at or near ":"
# LINE 1: ...."transaction_id" WHERE "psp"."app_brands"."id" = :key_value...
#                                                              ^
#
# [SQL: SELECT DISTINCT "psp"."app_log_gateway_callback".* FROM "psp"."app_brands"   LEFT JOIN "psp"."app_deposits" ON "psp"."app_brands"."id" = "psp"."app_deposits"."brand_id"  LEFT JOIN "psp"."app_log_gateway_callback" ON "psp"."app_deposits"."id" = "psp"."app_log_gateway_callback"."transaction_id" WHERE "psp"."app_brands"."id" = :key_value AND "psp"."app_log_gateway_callback"."transaction_id" IS NOT NULL]
# [parameters: {'key_value': 263}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# Data appended to exports/brands_dump.csv with query logged in exports/query_log.txt
# APPENDING TO app_log_gateway_callback next joins:  LEFT JOIN "psp"."app_deposits" ON "psp"."app_brands"."id" = "psp"."app_deposits"."brand_id" LEFT JOIN "psp"."app_log_gateway_callback" ON "psp"."app_deposits"."id" = "psp"."app_log_gateway_callback"."transaction_id"
# Current to process table  TO app_deposits prIMARY: app_third_party_update_log, COL deposit_id foreign app_deposits col id
# running for table -> app_third_party_update_log chunks with params {'key_value': 263} ----the query SELECT DISTINCT "psp"."app_third_party_update_log".* FROM "psp"."app_brands"   LEFT JOIN "psp"."app_deposits" ON "psp"."app_brands"."id" = "psp"."app_deposits"."brand_id"  LEFT JOIN "psp"."app_third_party_update_log" ON "psp"."app_deposits"."id" = "psp"."app_third_party_update_log"."deposit_id" WHERE "psp"."app_brands"."id" = :key_value AND "psp"."app_third_party_update_log"."deposit_id" IS NOT NULL
# An error occurred: (psycopg2.errors.SyntaxError) syntax error at or near ":"
# LINE 1: ...log"."deposit_id" WHERE "psp"."app_brands"."id" = :key_value...
#                                                              ^
#
# [SQL: SELECT DISTINCT "psp"."app_third_party_update_log".* FROM "psp"."app_brands"   LEFT JOIN "psp"."app_deposits" ON "psp"."app_brands"."id" = "psp"."app_deposits"."brand_id"  LEFT JOIN "psp"."app_third_party_update_log" ON "psp"."app_deposits"."id" = "psp"."app_third_party_update_log"."deposit_id" WHERE "psp"."app_brands"."id" = :key_value AND "psp"."app_third_party_update_log"."deposit_id" IS NOT NULL]
# [parameters: {'key_value': 263}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# Data appended to exports/brands_dump.csv with query logged in exports/query_log.txt
# APPENDING TO app_third_party_update_log next joins:  LEFT JOIN "psp"."app_deposits" ON "psp"."app_brands"."id" = "psp"."app_deposits"."brand_id" LEFT JOIN "psp"."app_third_party_update_log" ON "psp"."app_deposits"."id" = "psp"."app_third_party_update_log"."deposit_id"
# Current to process table  TO app_deposits prIMARY: app_transaction_updates, COL transaction_id foreign app_deposits col id
# running for table -> app_transaction_updates chunks with params {'key_value': 263} ----the query SELECT DISTINCT "psp"."app_transaction_updates".* FROM "psp"."app_brands"   LEFT JOIN "psp"."app_deposits" ON "psp"."app_brands"."id" = "psp"."app_deposits"."brand_id"  LEFT JOIN "psp"."app_transaction_updates" ON "psp"."app_deposits"."id" = "psp"."app_transaction_updates"."transaction_id" WHERE "psp"."app_brands"."id" = :key_value AND "psp"."app_transaction_updates"."transaction_id" IS NOT NULL
# An error occurred: (psycopg2.errors.SyntaxError) syntax error at or near ":"
# LINE 1: ...."transaction_id" WHERE "psp"."app_brands"."id" = :key_value...
#                                                              ^
#
# [SQL: SELECT DISTINCT "psp"."app_transaction_updates".* FROM "psp"."app_brands"   LEFT JOIN "psp"."app_deposits" ON "psp"."app_brands"."id" = "psp"."app_deposits"."brand_id"  LEFT JOIN "psp"."app_transaction_updates" ON "psp"."app_deposits"."id" = "psp"."app_transaction_updates"."transaction_id" WHERE "psp"."app_brands"."id" = :key_value AND "psp"."app_transaction_updates"."transaction_id" IS NOT NULL]
# [parameters: {'key_value': 263}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# Data appended to exports/brands_dump.csv with query logged in exports/query_log.txt
# APPENDING TO app_transaction_updates next joins:  LEFT JOIN "psp"."app_deposits" ON "psp"."app_brands"."id" = "psp"."app_deposits"."brand_id" LEFT JOIN "psp"."app_transaction_updates" ON "psp"."app_deposits"."id" = "psp"."app_transaction_updates"."transaction_id"
# Current to process table  TO app_payment_request_log previous JOINS joins:  LEFT JOIN "psp"."app_payment_request_log" ON "psp"."app_brands"."id" = "psp"."app_payment_request_log"."brand_id"
# Current to process table  TO app_payment_request_log previous RESULTS FETCHED: [('app_payment_request_log', 'brand_id', 'app_brands', 'id')]
# Current to process table  TO app_payment_request_log prIMARY: app_payment_request_log, COL brand_id foreign app_brands col id
# Current to process table  TO app_psp_settings previous JOINS joins:  LEFT JOIN "psp"."app_psp_settings" ON "psp"."app_brands"."id" = "psp"."app_psp_settings"."brand_id"
# Current to process table  TO app_psp_settings previous RESULTS FETCHED: [('app_deposits', 'payment_gateway_id', 'app_psp_settings', 'id'), ('app_fireblocks_address_pool', 'payment_gateway_id', 'app_psp_settings', 'id'), ('app_psp_rules', 'psp_id', 'app_psp_settings', 'id'), ('app_psp_settings', 'brand_id', 'app_brands', 'id')]
# Current to process table  TO app_psp_settings prIMARY: app_deposits, COL payment_gateway_id foreign app_psp_settings col id
# Current to process table  TO app_psp_settings prIMARY: app_fireblocks_address_pool, COL payment_gateway_id foreign app_psp_settings col id
# Current to process table  TO app_psp_settings prIMARY: app_psp_rules, COL psp_id foreign app_psp_settings col id
# Current to process table  TO app_psp_settings prIMARY: app_psp_settings, COL brand_id foreign app_brands col id
# Current to process table  TO app_user_brands previous JOINS joins:  LEFT JOIN "psp"."app_user_brands" ON "psp"."app_brands"."id" = "psp"."app_user_brands"."brand_id"
# Current to process table  TO app_user_brands previous RESULTS FETCHED: [('app_user_brands', 'brand_id', 'app_brands', 'id'), ('app_user_brands', 'user_id', 'users', 'id')]
# Current to process table  TO app_user_brands prIMARY: app_user_brands, COL brand_id foreign app_brands col id
# Current to process table  TO app_user_brands prIMARY: app_user_brands, COL user_id foreign users col id
# Current to process table  TO app_psp_rules previous JOINS joins:  LEFT JOIN "psp"."app_availability_rules" ON "psp"."app_brands"."id" = "psp"."app_availability_rules"."brand_id" LEFT JOIN "psp"."app_psp_rules" ON "psp"."app_availability_rules"."id" = "psp"."app_psp_rules"."rule_id"
# Current to process table  TO app_psp_rules previous RESULTS FETCHED: [('app_psp_rules', 'psp_id', 'app_psp_settings', 'id'), ('app_psp_rules', 'rule_id', 'app_availability_rules', 'id')]
# Current to process table  TO app_psp_rules prIMARY: app_psp_rules, COL psp_id foreign app_psp_settings col id
# Current to process table  TO app_psp_rules prIMARY: app_psp_rules, COL rule_id foreign app_availability_rules col id
# Current to process table  TO app_deposit_callbacks previous JOINS joins:  LEFT JOIN "psp"."app_deposits" ON "psp"."app_brands"."id" = "psp"."app_deposits"."brand_id" LEFT JOIN "psp"."app_deposit_callbacks" ON "psp"."app_deposits"."id" = "psp"."app_deposit_callbacks"."deposit_id"
# Current to process table  TO app_deposit_callbacks previous RESULTS FETCHED: [('app_deposit_callbacks', 'deposit_id', 'app_deposits', 'id')]
# Current to process table  TO app_deposit_callbacks prIMARY: app_deposit_callbacks, COL deposit_id foreign app_deposits col id
# Current to process table  TO app_fireblocks_address_pool previous JOINS joins:  LEFT JOIN "psp"."app_deposits" ON "psp"."app_brands"."id" = "psp"."app_deposits"."brand_id" LEFT JOIN "psp"."app_fireblocks_address_pool" ON "psp"."app_deposits"."id" = "psp"."app_fireblocks_address_pool"."transaction_id"
# Current to process table  TO app_fireblocks_address_pool previous RESULTS FETCHED: [('app_fireblocks_address_pool', 'payment_gateway_id', 'app_psp_settings', 'id'), ('app_fireblocks_address_pool', 'transaction_id', 'app_deposits', 'id')]
# Current to process table  TO app_fireblocks_address_pool prIMARY: app_fireblocks_address_pool, COL payment_gateway_id foreign app_psp_settings col id
# Current to process table  TO app_fireblocks_address_pool prIMARY: app_fireblocks_address_pool, COL transaction_id foreign app_deposits col id
# Current to process table  TO app_form_requests previous JOINS joins:  LEFT JOIN "psp"."app_deposits" ON "psp"."app_brands"."id" = "psp"."app_deposits"."brand_id" LEFT JOIN "psp"."app_form_requests" ON "psp"."app_deposits"."id" = "psp"."app_form_requests"."transaction_id"
# Current to process table  TO app_form_requests previous RESULTS FETCHED: [('app_form_requests', 'transaction_id', 'app_deposits', 'id')]
# Current to process table  TO app_form_requests prIMARY: app_form_requests, COL transaction_id foreign app_deposits col id
# Current to process table  TO app_log_gateway_callback previous JOINS joins:  LEFT JOIN "psp"."app_deposits" ON "psp"."app_brands"."id" = "psp"."app_deposits"."brand_id" LEFT JOIN "psp"."app_log_gateway_callback" ON "psp"."app_deposits"."id" = "psp"."app_log_gateway_callback"."transaction_id"
# Current to process table  TO app_log_gateway_callback previous RESULTS FETCHED: [('app_log_gateway_callback', 'transaction_id', 'app_deposits', 'id')]
# Current to process table  TO app_log_gateway_callback prIMARY: app_log_gateway_callback, COL transaction_id foreign app_deposits col id
# Current to process table  TO app_third_party_update_log previous JOINS joins:  LEFT JOIN "psp"."app_deposits" ON "psp"."app_brands"."id" = "psp"."app_deposits"."brand_id" LEFT JOIN "psp"."app_third_party_update_log" ON "psp"."app_deposits"."id" = "psp"."app_third_party_update_log"."deposit_id"
# Current to process table  TO app_third_party_update_log previous RESULTS FETCHED: [('app_third_party_update_log', 'deposit_id', 'app_deposits', 'id')]
# Current to process table  TO app_third_party_update_log prIMARY: app_third_party_update_log, COL deposit_id foreign app_deposits col id
# Current to process table  TO app_transaction_updates previous JOINS joins:  LEFT JOIN "psp"."app_deposits" ON "psp"."app_brands"."id" = "psp"."app_deposits"."brand_id" LEFT JOIN "psp"."app_transaction_updates" ON "psp"."app_deposits"."id" = "psp"."app_transaction_updates"."transaction_id"
# Current to process table  TO app_transaction_updates previous RESULTS FETCHED: [('app_transaction_updates', 'transaction_id', 'app_deposits', 'id')]
# Current to process table  TO app_transaction_updates prIMARY: app_transaction_updates, COL transaction_id foreign app_deposits col id
# Related tables: {'app_payment_request_log', 'app_brands', 'app_deposits', 'app_form_requests', 'app_log_gateway_callback', 'app_fireblocks_address_pool', 'app_deposit_callbacks', 'app_third_party_update_log', 'app_user_brands', 'app_transaction_updates', 'app_psp_rules', 'app_availability_rules', 'app_api_keys', 'app_psp_settings'}
# Related tables have been written to exports/related_tables_output.txt
